# %%
import pandas as pd
from pandas.io import gbq
from datetime import datetime


df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRhcAWkWXIjp2XVAsnTLw13QGg6Ot9D_HBf_FMCA42qIWf034T8oKOgV6cTBJS29tfJRPHPyQ4DQJ6s/pub?gid=1335506491&single=true&output=csv")
pd.set_option('display.max_columns', None)

#cleaning columns
replace = {' ' : '_', '-' : '_', '.' : '_', '?' : '', '[' : '', ']' : '', '(' : '', ')' : ''}

def clean_col (col, clean_col):
  col.columns = col.columns.str.lower()
  for i, j in clean_col.items():
    col.columns = col.columns.str.replace(i, j)
  return col

df = df.rename({"Timestamp":"last_record"}, axis=1)
df["timestamp"] = pd.to_datetime("now")

df_2 = clean_col(df, replace)
df_2 = df_2.astype(str)

def timestamp_convert(date_to_convert):
     return datetime.strptime(date_to_convert, '%Y-%m-%d %H:%M:%S.%f').strftime('%Y-%m-%d')

df_2['timestamp'] = df_2['timestamp'].apply(timestamp_convert)

df_2.head()
# Out:
# /home/alfian/miniconda3/envs/w4c/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
# /tmp/ipykernel_11441/3768337205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   col.columns = col.columns.str.replace(i, j)
#           last_record                      email_address date_leads_acquired  \
# 0   4/22/2022 7:54:13     maria.theresa@waste4change.com            1/4/2022
# 1  6/20/2022 14:23:14     maria.theresa@waste4change.com           1/27/2022
# 2   3/25/2022 9:13:01  puteri.modiyanti@waste4change.com           1/20/2022
# 3  3/16/2022 10:07:56     andin.refiana@waste4change.com           9/24/2021
# 4   3/25/2022 9:54:43     andin.refiana@waste4change.com           1/25/2022
#
#   client_organization new_client_organization_name  \
# 0                HSBC                          nan
# 1                 nan              PT Petrosea Tbk
# 2                 nan                     Tripatra
# 3                PPLi                          nan
# 4                 nan                   Super Indo
#
#                                     project_name w4c_pic  \
# 0   Waste Bin and Waste Management Campaign HSBC   Thesa
# 1                                Comdev Petrosea   Thesa
# 2                   AKABIS BSF Workshop Tripatra  Puteri
# 3  Post-Consumption Tires Material Flow Analysis   Andin
# 4     Material Circularity Assessment Super Indo   Andin
#
#   client_organization_type new_client_organization_type  \
# 0         Company (Swasta)                          nan
# 1         Company (Swasta)                          nan
# 2         Company (Swasta)                          nan
# 3         Company (Swasta)                          nan
# 4         Company (Swasta)                          nan
#
#   client_organization_industry new_client_organization_industry  \
# 0                      Banking                              nan
# 1                          nan                           Mining
# 2                          nan                     Construction
# 3                          nan                              nan
# 4                          nan                              nan
#
#   client_organization_size                       client_organization_location  \
# 0                      nan  Jabodetabek (Jakarta, Bogor, Depok, Tangerang,...
# 1                      nan  Jabodetabek (Jakarta, Bogor, Depok, Tangerang,...
# 2                      nan  Jabodetabek (Jakarta, Bogor, Depok, Tangerang,...
# 3                      nan  Jabodetabek (Jakarta, Bogor, Depok, Tangerang,...
# 4                      nan  Jabodetabek (Jakarta, Bogor, Depok, Tangerang,...
#
#        client_pic                       client_pic_position  \
# 0           Affan                                       nan
# 1   Qonita Addina                               CSR Officer
# 2     Faiz Sujudi  Corporate Communication & Sustainability
# 3  Lely Fitriyani              Business Development Manager
# 4            Arya                                       nan
#
#         client_phone                 client_email       lead_status  \
# 0  +62 812-1207-4010                          nan           No Deal
# 1     0812-1977-6094   qonita.Addina@petrosea.com  Project Greenlit
# 2       081381948887     faiz.sujudi@tripatra.com           On Hold
# 3   +62 811-9003-016    lely.fitriyani@ppli.co.id  Project Greenlit
# 4  +62 812-8288-9400  arya.kusumo@superindo.co.id           No Deal
#
#                       service_type     service_topic new_service_topic chance  \
# 0             Community Engagement  Waste Management               nan    4.0
# 1            Community Development               nan               nan    4.0
# 2                  AKABIS Workshop               nan               nan    3.0
# 3  Solid Waste Management Research  Waste Management               nan    5.0
# 4  Solid Waste Management Research  Waste Management               nan    3.0
#
#   date_project_decided date_proposal_sent number_of_proposal_revision  \
# 0                  nan           2/2/2022                         nan
# 1            3/14/2022          2/25/2022                         0.0
# 2                  nan          1/25/2022                         nan
# 3           12/30/2021         11/22/2021                         1.0
# 4            3/21/2022          2/14/2022                         nan
#
#   operational_value non_ss_operational_value in_house_consultant_involved  \
# 0        13500000.0               69950000.0                          nan
# 1        37100000.0                      nan                       Tantin
# 2         6600000.0                      nan                         Khai
# 3        71470000.0                      nan                         Anin
# 4        35950000.0                      nan        Project Professionals
#
#   total_personnel_value_albert total_billed_days_albert  \
# 0                          nan                      nan
# 1                          nan                      nan
# 2                          nan                      nan
# 3                          nan                      nan
# 4                          nan                      nan
#
#   other_in_house_consultant total_personnel_value_anin total_billed_days_anin  \
# 0                       nan                        nan                    nan
# 1                       nan                        nan                    nan
# 2                       nan                        nan                    nan
# 3                       nan                 29260000.0                   22.0
# 4                       nan                        nan                    nan
#
#   other_in_house_consultant_1 total_personnel_value_april  \
# 0                         nan                         nan
# 1                         nan                         nan
# 2                         nan                         nan
# 3       Project Professionals                         nan
# 4                         nan                         nan
#
#   total_billed_days_april other_in_house_consultant_2  \
# 0                     nan                         nan
# 1                     nan                         nan
# 2                     nan                         nan
# 3                     nan                         nan
# 4                     nan                         nan
#
#   total_personnel_value_elma total_billed_days_elma  \
# 0                        nan                    nan
# 1                        nan                    nan
# 2                        nan                    nan
# 3                        nan                    nan
# 4                        nan                    nan
#
#   other_in_house_consultant_3 total_personnel_value_fitria  \
# 0                         nan                          nan
# 1                         nan                          nan
# 2                         nan                          nan
# 3                         nan                          nan
# 4                         nan                          nan
#
#   total_billed_days_fitria other_in_house_consultant_4  \
# 0                      nan                         nan
# 1                      nan                         nan
# 2                      nan                         nan
# 3                      nan                         nan
# 4                      nan                         nan
#
#   total_personnel_value_ica total_billed_days_ica other_in_house_consultant_5  \
# 0                       nan                   nan                         nan
# 1                       nan                   nan                         nan
# 2                       nan                   nan                         nan
# 3                       nan                   nan                         nan
# 4                       nan                   nan                         nan
#
#   total_personnel_value_ifa total_billed_days_ifa other_in_house_consultant_6  \
# 0                       nan                   nan                         nan
# 1                       nan                   nan                         nan
# 2                       nan                   nan                         nan
# 3                       nan                   nan                         nan
# 4                       nan                   nan                         nan
#
#   total_personnel_value_khai total_billed_days_khai  \
# 0                        nan                    nan
# 1                        nan                    nan
# 2                 10650000.0                    3.0
# 3                        nan                    nan
# 4                        nan                    nan
#
#   other_in_house_consultant_7 total_personnel_value_prita  \
# 0                         nan                         nan
# 1                         nan                         nan
# 2                         nan                         nan
# 3                         nan                         nan
# 4                         nan                         nan
#
#   total_billed_days_prita other_in_house_consultant_8  \
# 0                     nan                         nan
# 1                     nan                         nan
# 2                     nan                         nan
# 3                     nan                         nan
# 4                     nan                         nan
#
#   total_personnel_value_saka total_billed_days_saka  \
# 0                        nan                    nan
# 1                        nan                    nan
# 2                        nan                    nan
# 3                        nan                    nan
# 4                        nan                    nan
#
#   other_in_house_consultant_9 total_personnel_value_tantin  \
# 0                         nan                          nan
# 1                         nan                   25270000.0
# 2                         nan                          nan
# 3                         nan                          nan
# 4                         nan                          nan
#
#   total_billed_days_tantin other_in_house_consultant_10  \
# 0                      nan                          nan
# 1                     19.0        Project Professionals
# 2                      nan                          nan
# 3                      nan                          nan
# 4                      nan                          nan
#
#   number_of_other_in_house_consultants names_of_in_house_consultant  \
# 0                                  nan                          nan
# 1                                  nan                          nan
# 2                                  nan                          nan
# 3                                  nan                          nan
# 4                                  nan                          nan
#
#   total_personnel_value_other total_billed_days_other  \
# 0                         nan                     nan
# 1                         nan                     nan
# 2                         nan                     nan
# 3                         nan                     nan
# 4                         nan                     nan
#
#   other_in_house_consultant_11 total_analyst_personnel_value  \
# 0                          nan                           nan
# 1                          nan                     3200000.0
# 2                          nan                           nan
# 3                          nan                           nan
# 4                          nan                           nan
#
#   total_analyst_billed_days total_associate_personnel_value  \
# 0                       nan                             nan
# 1                      16.0                     108652500.0
# 2                       nan                             nan
# 3                       nan                     175720000.0
# 4                       nan                     131560000.0
#
#   total_associate_billed_days total_consultant_personnel_value  \
# 0                         nan                              nan
# 1                        99.0                              nan
# 2                         nan                              nan
# 3                       191.0                              nan
# 4                       143.0                        1330000.0
#
#   total_consultant_billed_days other_in_house_consultant_12 proposed_cogs  \
# 0                          nan                          nan    16365250.0
# 1                          nan           No Other Personnel    64571175.0
# 2                          nan                          nan           nan
# 3                          nan           No Other Personnel   165260550.0
# 4                         21.0           No Other Personnel    84568700.0
#
#   proposed_project_start_date proposed_project_end_date nsm_projection  \
# 0                         nan                       nan            nan
# 1                    9/1/2022                12/31/2022            nan
# 2                    3/1/2022                       nan            nan
# 3                    2/1/2022                 6/30/2022            nan
# 4                    3/1/2022                 7/30/2022            nan
#
#   project_strategic_index_projection_profit_margin  \
# 0                                              6.0
# 1                                              7.0
# 2                                              nan
# 3                                              4.0
# 4                                              8.0
#
#   project_strategic_index_projection_repicability_to_market  \
# 0                                                7.0
# 1                                                7.0
# 2                                                nan
# 3                                                9.0
# 4                                                6.0
#
#   project_strategic_index_projection_influencing_decision_maker  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                9.0
# 4                                                9.0
#
#   project_strategic_index_projection_contributes_to_swm_intelligence  \
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                                                8.0
# 4                                                9.0
#
#   project_strategic_index_projection_catalyzing_behaviour_change  \
# 0                                                7.0
# 1                                                9.0
# 2                                                nan
# 3                                                5.0
# 4                                                nan
#
#   project_strategic_index_projection_quantity_of_beneficiaries  \
# 0                                                7.0
# 1                                                5.0
# 2                                                nan
# 3                                                5.0
# 4                                                nan
#
#   project_strategic_index_projection_ease_of_implementation  \
# 0                                                6.0
# 1                                                7.0
# 2                                                nan
# 3                                                5.0
# 4                                                6.0
#
#   project_strategic_index_projection_supports_nsm_financially  \
# 0                                                6.0
# 1                                                6.0
# 2                                                nan
# 3                                                4.0
# 4                                                2.0
#
#   project_strategic_index_projection_supports_nsm_strategically  \
# 0                                                7.0
# 1                                                7.0
# 2                                                nan
# 3                                                7.0
# 4                                                5.0
#
#   delegation_date contract_status contract_signature_date  \
# 0             nan             nan                     nan
# 1             nan        Drafting                     nan
# 2             nan             nan                     nan
# 3       1/12/2022          Signed              12/30/2021
# 4             nan             nan                     nan
#
#   terms_of_payment_quantity term_of_payment_value          milestone  \
# 0                       nan                   nan                nan
# 1                       1.0           174222500.0                nan
# 2                       nan                   nan                nan
# 3                       2.0           138225000.0  Setelah PO Terbit
# 4                       nan                   nan                nan
#
#   estimated_date_of_milestone_delivery final_term_of_payment  \
# 0                                  nan                   Yes
# 1                                  nan                   Yes
# 2                                  nan                   nan
# 3                                  nan                    No
# 4                                  nan                   Yes
#
#   term_of_payment_value_1              milestone_1  \
# 0                     nan                      nan
# 1                     nan                      nan
# 2                     nan                      nan
# 3             138225000.0  Final Report Submission
# 4                     nan                      nan
#
#   estimated_date_of_milestone_delivery_1 final_term_of_payment_1  \
# 0                                    nan                     nan
# 1                                    nan                     nan
# 2                                    nan                     nan
# 3                              6/30/2022                     Yes
# 4                                    nan                     nan
#
#   term_of_payment_value_2 milestone_2 estimated_date_of_milestone_delivery_2  \
# 0                     nan         nan                                    nan
# 1                     nan         nan                                    nan
# 2                     nan         nan                                    nan
# 3                     nan         nan                                    nan
# 4                     nan         nan                                    nan
#
#   final_term_of_payment_2 term_of_payment_value_3 milestone_3  \
# 0                     nan                     nan         nan
# 1                     nan                     nan         nan
# 2                     nan                     nan         nan
# 3                     nan                     nan         nan
# 4                     nan                     nan         nan
#
#   estimated_date_of_milestone_delivery_3 final_term_of_payment_3  \
# 0                                    nan                     nan
# 1                                    nan                     nan
# 2                                    nan                     nan
# 3                                    nan                     nan
# 4                                    nan                     nan
#
#   term_of_payment_value_4 milestone_4 estimated_date_of_milestone_delivery_4  \
# 0                     nan         nan                                    nan
# 1                     nan         nan                                    nan
# 2                     nan         nan                                    nan
# 3                     nan         nan                                    nan
# 4                     nan         nan                                    nan
#
#   final_term_of_payment_4 other_terms_of_payment date_leads_defined  \
# 0                     nan                    nan                nan
# 1                     nan                    nan                nan
# 2                     nan                    nan                nan
# 3                     nan                    nan                nan
# 4                     nan                    nan                nan
#
#                                      source_of_leads   timestamp
# 0                                                nan  2022-11-28
# 1                                                nan  2022-11-28
# 2                                                nan  2022-11-28
# 3                                                nan  2022-11-28
# 4  CE Effort (Social Media W4C, Webform, WhatsApp...  2022-11-28
